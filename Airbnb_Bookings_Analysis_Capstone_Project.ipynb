# %% [markdown]
# <a href="https://colab.research.google.com/github/amanichivilkar/Airbnb-Booking-Analysis/blob/main/Airbnb_Bookings_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <b> Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. </b>
#
# <b>This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values. </b>
#
# <b> Explore and analyze the data to discover key understandings (not limited to these) such as :
# * What can we learn about different hosts and areas?
# * What can we learn from predictions? (ex: locations, prices, reviews, etc)
# * Which hosts are the busiest and why?
# * Is there any noticeable difference of traffic among different areas and what could be the reason for it? </b>

# %% [markdown]
# ###**Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="whitegrid")
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ### **Get the Dataset path file**

# %%
df=pd.read_csv("/content/drive/MyDrive/data/Copy of Airbnb NYC 2019.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %% [markdown]
# ### **Understanding the column of the DataFrame**

# %% [markdown]
#  Columns of the DataFrame
#
# * **Id-** It is listing id. Whenever a host list its property on Airbnb, a unique id is created, since every id is unique there are 458895 unique id.
# As per my observation ,every listing is a listing of unique properties.(means the same property is not listed more than 1)
# * **name-** It is the property description. Two properties can have the same name, but they are not the same property, every property in the data are unique, as all of them are having different longitude and latitude, that means every properties are situated in different location.
# * **host_id-** Its the identity id given to individual host (For example- two different host cant have the same host_id). So if we want to count the number of host, we count the unique host_id.
# * **neighbourhood_group-** This are the 5 Boroughs of New York city, in which the property is located.
# * **neighbourhood-**  This are the towns and villages in New York
# * **room_type-** Types of properties
# * **price-**  Property price per day
# * **minimum_nights-** It is the minimum number of night you can book a property,( example-1 year rental contract)
# * **number_of_reviews-** Total number of reviews
# * **Calculated_host_listing_count-** The number of times the host has listed its property.
# * **availabilitty_365-** the number of days the property were available for booking.

# %% [markdown]
# * Drop the column which are not required,like id
# * Since 2 different host can have the same host_name, we use host_id , as host id is unique for induvidual host

# %% [markdown]
# ## **Cleaning the data**

# %% [markdown]
# ### **Check how many NaN values are present in each columns**

# %%
 df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ### **Drop unecessary  column like "id"**

# %%
df.drop(['id'], axis=1,inplace=True)

# %% [markdown]
# ###  **Fill the NaN values in host_name by 'no name'**

# %%
df.loc[df.host_name.isna(),'host_name']=df.loc[df.host_name.isna(),'host_name'].apply(lambda x: "no name")

# %% [markdown]
# ### **Replace NaN values in 'name' column by 'no description'**

# %%
df.loc[df.name.isna(),'name']=df.loc[df.name.isna(),'name'].apply(lambda x: "no description")

# %% [markdown]
# ### **Replace NaN values in 'reviews_per_month' column by 0**

# %%
df.loc[df.reviews_per_month.isna(),'reviews_per_month']=df.loc[df.reviews_per_month.isna(),'reviews_per_month'].apply(lambda x: 0)

# %% [markdown]
# ### **If price is 0 , replace it by the average price of all similar room_type with similar neighbourhood_group**

# %%
#Considering 3 column of the dataframe df
df1=df[['neighbourhood_group','room_type','price']]

#Create dataframe df2 containig price greater than zero
df2=df1[df1.price!=0]

# groupby neighbourhood_group and room_type, And find there average price 
df3=df2.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()
df3
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     127.506596     66.890937    59.800000
# Brooklyn                  178.346202     76.545428    50.773723
# Manhattan                 249.257994    116.776622    88.977083
# Queens                    147.050573     71.762456    69.020202
# Staten Island             173.846591     62.292553    57.444444

# %%
# Creat function to extract average price from dataframe df3
def fun(neighbourhood_group,room_type):
 avg_price=df3.loc[neighbourhood_group,room_type]
 return avg_price

# %%
# Repllace 0 price by the average price from the dataframe df3
df['price']=df.apply(lambda x: fun(x['neighbourhood_group'],x['room_type'])  if x['price']==0 else x['price'], axis=1 )

# %%
df.price.describe()
# Out:
# count    48895.00000
# mean       152.74227
# std        240.14635
# min         10.00000
# 25%         69.00000
# 50%        106.00000
# 75%        175.00000
# max      10000.00000
# Name: price, dtype: float64

# %% [markdown]
# ### **Find the outliers of price column**

# %%
df.price.plot(kind='box')
plt.title("Room price", fontsize=20)
plt.xlabel("Room type", fontsize =15)
plt.ylabel("price", fontsize =15)
# Out:
# Text(0, 0.5, 'price')

# %%
# Finding Q1, Q3 and IQR
Q1 =  df['price'].quantile(0.25) #25%
Q3 = df['price'].quantile(0.75) # 75%
IQR = Q3 - Q1

# %%
# The outlier price
df[(df['price'] < Q1-1.5*IQR ) | (df['price'] > Q3+1.5*IQR)]['price']
# Out:
# 61       375.0
# 85       800.0
# 103      500.0
# 114      350.0
# 121      400.0
#          ...
# 48758    350.0
# 48833    475.0
# 48839    800.0
# 48842    350.0
# 48856    345.0
# Name: price, Length: 2972, dtype: float64

# %%
# Count the outlier
df[(df['price'] < Q1-1.5*IQR ) | (df['price'] > Q3+1.5*IQR)]['price'].count()
# Out:
# 2972

# %%
# Remove outliers from our data set
outliers = (df['price'] >= Q1 - 1.5 * IQR) & (df['price'] <= Q3 + 1.5 *IQR)
df= df.loc[outliers]

# %%
# Box plot after removing the outliers
df.price.plot(kind='box')
plt.title("Room price", fontsize=20)
plt.xlabel("Room type", fontsize =15)
plt.ylabel("price", fontsize =15)
# Out:
# Text(0, 0.5, 'price')

# %%
df.price.describe()
# Out:
# count    45923.00000
# mean       119.99330
# std         68.13185
# min         10.00000
# 25%         65.00000
# 50%        100.00000
# 75%        159.00000
# max        334.00000
# Name: price, dtype: float64

# %% [markdown]
# ### **Convert timestring to datetime**

# %%
df.loc[~df['last_review'].isna(),'last_review']=df.loc[~df['last_review'].isna(),'last_review'].apply(lambda x: datetime.strptime(x,'%Y-%m-%d'))

# %% [markdown]
# ###  **Verify cleaned Data**

# %%
# check the nan values
df.isnull().sum()
# Out:
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       9012
# reviews_per_month                    0
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %% [markdown]
# # **EDA and Visualization Analysis**

# %% [markdown]
# **define busiest host**
# I would consider the host to be busy, if he frequently receives bookings (that is if the host recives booking  in higher rate).
# Since we have not been provided with the booking data, we can consider the number of reviews received  by the host as the minimum number of booking that a host could get. (since the tenants gives review after booking/using the property)
#
# * host with maximum number of reviews is not busiest, but host with max number of reviews per month is the busiest.
# * For example host1 gets 10 booking per month is more busier than the host2 who gets 2 booking per month.

# %% [markdown]
# ##**HOST_ID**

# %% [markdown]
# ### Count the number of unique host that has listed properties on Airbnb

# %% [markdown]
#
#
# *    Since 2 different host can have the same host_name, so we use host_id.
#
# *    host id is unique for individual host

# %%
unique_host_id =df['host_id'].value_counts().reset_index().rename(columns={'index':'host_id','host_id':'listing_counts'})
unique_host_id
# Out:
#          host_id  listing_counts
# 0      219517861             272
# 1      107434423             180
# 2      137358866             103
# 3       12243051              95
# 4       30283594              95
# ...          ...             ...
# 35384   95485067               1
# 35385  167560332               1
# 35386  263742622               1
# 35387  205706382               1
# 35388    1288080               1
#
# [35389 rows x 2 columns]

# %% [markdown]
# *  This shows the count of listings of particular host id on Airbnb.
# But we want total number of unique host ids
# *   We apply lenght function to above dataframe to get total number of unique host ids

# %%
len(unique_host_id)
# Out:
# 35389

# %% [markdown]
# **Airbnb has 35389 unique host ids or host owner**

# %% [markdown]
# ## **REVIEWS_PER_MONTH**

# %% [markdown]
# ### Find the rate of reviews per month, received by each host for all its properties (combined) listed on Airbnb

# %%
#Create new column 'reviews_in_days'
df['reviews_in_days']=(df.number_of_reviews/df.reviews_per_month)*31 # This calculation gives reviews_in_month, we multiply it by 31 to get reviews in days

# %%
# considerng the following columns only from the original dataframe
df1=df[['host_id','host_name','number_of_reviews','last_review','reviews_in_days']]
df1.dropna(inplace=True)
df1.head()
# Out:
#    host_id    host_name  ...          last_review reviews_in_days
# 0     2787         John  ...  2018-10-19 00:00:00     1328.571429
# 1     2845     Jennifer  ...  2019-05-21 00:00:00     3671.052632
# 3     4869  LisaRoxanne  ...  2019-07-05 00:00:00     1803.879310
# 4     7192        Laura  ...  2018-11-19 00:00:00     2790.000000
# 5     7322        Chris  ...  2019-06-22 00:00:00     3888.135593
#
# [5 rows x 5 columns]

# %%
#Convert reviews_in_days columns into deltatime and store it in a
a=pd.to_timedelta(df1['reviews_in_days'], unit='D')

# %%
#create new column "first_review" that stors the date of the first review
df1['first_review']=df1['last_review']-a
df1.head()
# Out:
#    host_id    host_name  ...  reviews_in_days                  first_review
# 0     2787         John  ...      1328.571429 2015-02-28 10:17:08.571465600
# 1     2845     Jennifer  ...      3671.052632 2009-05-01 22:44:12.631574400
# 3     4869  LisaRoxanne  ...      1803.879310 2014-07-27 02:53:47.586192000
# 4     7192        Laura  ...      2790.000000 2011-03-31 00:00:00.000000000
# 5     7322        Chris  ...      3888.135593 2008-10-28 20:44:44.745792001
#
# [5 rows x 6 columns]

# %%
df1
# Out:
#          host_id    host_name  ...  reviews_in_days                  first_review
# 0           2787         John  ...      1328.571429 2015-02-28 10:17:08.571465600
# 1           2845     Jennifer  ...      3671.052632 2009-05-01 22:44:12.631574400
# 3           4869  LisaRoxanne  ...      1803.879310 2014-07-27 02:53:47.586192000
# 4           7192        Laura  ...      2790.000000 2011-03-31 00:00:00.000000000
# 5           7322        Chris  ...      3888.135593 2008-10-28 20:44:44.745792001
# ...          ...          ...  ...              ...                           ...
# 48782   83554966        Rusaa  ...        31.000000 2019-06-06 00:00:00.000000000
# 48790  257683179         H Ai  ...        31.000000 2019-06-06 00:00:00.000000000
# 48799  211644523          Ben  ...        31.000000 2019-06-06 00:00:00.000000000
# 48805  273841667       Blaine  ...        31.000000 2019-06-06 00:00:00.000000000
# 48852   74162901    Christine  ...        31.000000 2019-06-07 00:00:00.000000000
#
# [36911 rows x 6 columns]

# %%
# groupby host id and find out the min of the first_review and max of the last_review and sum up all the number of reviews recieved by each host for all its properties
df2=df1.groupby(['host_id','host_name']).agg({'number_of_reviews':'sum','first_review':np.min,'last_review':np.max}).reset_index().rename(columns={'number_of_reviews':'total_reviews','first_review':'min_first_review','last_review':'max_last_review'})
df2.head()
# Out:
#    host_id host_name  ...              min_first_review max_last_review
# 0     2438     Tasos  ... 2016-10-16 07:59:59.999971200      2018-03-17
# 1     2571     Teedo  ... 2013-03-10 20:06:29.189203200      2019-05-21
# 2     2787      John  ... 2015-02-28 10:17:08.571465600      2019-06-26
# 3     2845  Jennifer  ... 2009-05-01 22:44:12.631574400      2019-05-21
# 4     2868  Letha M.  ... 2014-10-01 16:00:00.000028800      2017-07-31
#
# [5 rows x 5 columns]

# %%
# Create the difference column by subtracting the max_last_review from the min_first_review
df2['Difference'] = df2['max_last_review'].sub(df2['min_first_review'], axis=0)
# Ectract days from Difference(datetime) column
df2['Difference'] = df2['Difference'].apply(lambda x: x.days)
# This dfference is in days we convert it into months by dividing it by 31days
df2['Difference'] = df2['Difference']/31
df2.rename(columns={'Difference':'Difference_in_months'},inplace=True)
df2.head()
# Out:
#    host_id host_name  ...  max_last_review Difference_in_months
# 0     2438     Tasos  ...       2018-03-17            16.645161
# 1     2571     Teedo  ...       2019-05-21            72.967742
# 2     2787      John  ...       2019-06-26            50.903226
# 3     2845  Jennifer  ...       2019-05-21           118.419355
# 4     2868  Letha M.  ...       2017-07-31            33.322581
#
# [5 rows x 6 columns]

# %%
# rate of reviews per month, recieved by each host for all its properties (combined) listed on Airbnb
df2['total_reviews_per_month']=(df2.total_reviews/df2.Difference_in_months)
df6=df2.sort_values('total_reviews_per_month', ascending=False).head()
df6
# Out:
#          host_id     host_name  ...  Difference_in_months total_reviews_per_month
# 27043  219517861  Sonder (NYC)  ...              6.290323              150.389744
# 27911  244361589       Row NYC  ...              4.258065               71.628788
# 27613  232251881      Lakshmee  ...              6.774194               71.152381
# 14731   26432133      Danielle  ...             32.129032               62.778112
# 24196  137274917         David  ...             11.838710               51.272480
#
# [5 rows x 7 columns]

# %%
df1=df[(df.host_id==219517861)|(df.host_id==244361589)|(df.host_id==232251881)|(df.host_id==26432133)|(df.host_id==137274917)]

# %%
df2=df1.groupby(['host_name'])['calculated_host_listings_count'].count().reset_index()
df3=df1.groupby(['host_name'])['number_of_reviews'].sum().reset_index()
df4=df1.groupby(['host_name'])['minimum_nights'].median().reset_index()
df5=df1.groupby(['host_name'])['price'].mean().reset_index()


plt.figure(figsize=(25,8))

plt.subplot(2,4,3)
sns.barplot(x=df2.host_name, y=df2.calculated_host_listings_count)

plt.subplot(2,4,2)
sns.barplot(x=df6.host_name, y=df6.total_reviews_per_month)

plt.subplot(2,4,1)
sns.barplot(x=df3.host_name, y=df3.number_of_reviews)

plt.subplot(2,4,5)
sns.barplot(x=df4.host_name, y=df4.minimum_nights)

plt.subplot(2,4,4)
sns.barplot(x=df5.host_name, y=df5.price)

# %% [markdown]
# * Sonder has the highest review per month, highest listing count, and most of his properties are in Manhattan which is the most densely populated among the 5 boroughs of New York city. Hence Sonder is the busiest host.
#
# * Most of his properties are entire home/apt, with an average price of 251$ and the minimum_night stay is 2 nights.
#
# * In the given data Danielle has the highest number of reviews that is 2017 reviews. but the rate of reviews is 62 reviews per month, where as Soder got 946 reviews , and the rate of reviews is 150 reviews per month , means Sonders booking rate is more than Danielle, hence Sonder is the busiest among all.

# %% [markdown]
# ## ***HOST_LISTING_COUNT***

# %% [markdown]
# ### Top 5 host with highest listing counts

# %%
#Top 5 host with max number of listing
df1=df.groupby(['host_id','host_name']).agg({'calculated_host_listings_count':'count','number_of_reviews':'sum','minimum_nights':'median'}).reset_index().sort_values('calculated_host_listings_count', ascending=False).head()

plt.figure(figsize=(20,5))

plt.subplot(1,3,1)
sns.barplot(x=df1.host_name, y=df1.calculated_host_listings_count)

plt.subplot(1,3,2)
sns.barplot(x=df1.host_name, y=df1.number_of_reviews)

plt.subplot(1,3,3)
sns.barplot(x=df1.host_name, y=df1.minimum_nights)

# %% [markdown]
# * Inspite of Blueground having the second highest listing count, he has got very less reviews among all, that is because the minimum night required to book Blueground's property is 30 nights. where as for Sonder is 2 nights, this implies lesser the minimumnight, higher is the review
#
# * Scatterplot  below shows the relation between minimum_nights and total_reviews of all the host

# %%
h=df[['minimum_nights','number_of_reviews']]
corr_h=h.corr()
sns.heatmap(corr_h,annot=True)
sns.pairplot(h)

# %% [markdown]
# * minimum_nights and total_reviews of all the host are negatively correlated

# %% [markdown]
# ### Properties location on map and the percentage of each property type in different neighbourhood group listed on Airbnb

# %%
i=1
plt.figure(figsize=(20,30))
for city in ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx']:
  df1=df[df.neighbourhood_group==city].groupby(['room_type'])['name'].count()
  df2=df[df.neighbourhood_group==city]

  plt.subplot(5,2,i)
  sns.scatterplot(y=df2.latitude,x=df2.longitude,hue=df2.room_type, size=df2.room_type, sizes=(250,50)).set(title=f'Property type in {city}')
  plt.subplot(5,2,i+1)
  df1.plot.pie(autopct="%.1f%%")
  i=i+2

# %% [markdown]
# ### Number and Percentage of Properties, listed on Airbnb

# %%
 
plt.figure(figsize=(20,25))
 
df1=df.groupby(['room_type'])['name'].count().reset_index().rename(columns={'name':'listing_count_of_properties'})
df7=df.groupby(['room_type'])['name'].count()
df4=df.groupby(['neighbourhood_group'])['name'].count().reset_index().rename(columns={'name':'listing_count_of_properties'})
df5=df.groupby(['neighbourhood_group'])['name'].count()
df6=df.groupby(['neighbourhood_group','room_type'])['name'].count().reset_index().rename(columns={'name':'listing_count_of_properties'})
 
plt.subplot(4,3,1)
sns.barplot(x=df1.room_type, y=df1.listing_count_of_properties).set(title='Number of different property types')
plt.subplot(4,3,2)
df7.plot.pie(autopct="%.1f%%")
 
i=4
for room in ['Entire home/apt','Private room', 'Shared room']:
  df2=df[df.room_type==room] 
  df3=df2.groupby(['neighbourhood_group'])['name'].count()
 
  plt.subplot(4,3,i)
  plt.title(f'{room} distribution%')
  df3.plot.pie(autopct="%.1f%%")
  i=i+1
 
plt.subplot(4,3,7)
sns.barplot(x=df4.neighbourhood_group, y=df4.listing_count_of_properties).set(title='Number of properties in different neighbourhood_group')
plt.subplot(4,3,8)
df5.plot.pie(autopct="%.1f%%")

 
plt.subplot(4,3,10)
sns.barplot(x=df6.neighbourhood_group, y=df6.listing_count_of_properties, hue=df6.room_type).set(title='Number of different property types in different neighbourhood_group')
# Out:
# [Text(0.5, 1.0, 'Number of different property types in different neighbourhood_group')]

# %% [markdown]
# * Entire home/apt is highest room type listed on Airbnb , Where as Shared room is the second highest room_type listed on Airbnb.
# The least room_type is the sharedroom , which is about 2.5% of the entire properties listed on Airbnb.
# * Manhattan is the smallest neighborhood_group, but has about 42.5% of the properties listed on Airbnb, that's because it is densely populated city of New York.
# * The maximum number of Entire home/apt listed on Airbnb are situated in Manhattan, maximum number of Private room are situated in Brooklyn, second highest number of Private room are situated situated in Manhattan.
# Staten Island and Bronx has the very less number properties.
# * Staten and Bronx has very less number of properties listed on Airbnb. 2.3% of the entire properties listed on Airbnb are situated in Bronx and only 0.8% are situated in Staten Island

# %% [markdown]
# ## **PRICE**

# %% [markdown]
# ### Price of properties in different neighbourgood group showing on a map

# %%
i=1
plt.figure(figsize=(25,20))
for city in ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx']:
 #df1=df[df.neighbourhood_group==city].groupby(['room_type'])['name'].nunique()
 df2=df[df.neighbourhood_group==city]
 

 plt.subplot(3,3,i)
 sns.scatterplot(y=df2.latitude, x=df2.longitude, hue=df2.price, size=df2.price, sizes=(20, 250) ).set(title=f'price range in {city}')
 i=i+1

# %% [markdown]
# ### Average price of Properties

# %%
df1=df.groupby(['room_type'])['price'].mean().reset_index().rename(columns={'price':'avg_price'})
df2=df.groupby(['neighbourhood_group'])['price'].mean().reset_index().rename(columns={'price':'avg_price'})
df3=df.groupby(['neighbourhood_group','room_type'])['price'].mean().reset_index().rename(columns={'price':'avg_price'})

fig, ax=plt.subplots(1,3,figsize=(20,3))
fig.suptitle('Average price of the properties') 

sns.barplot(ax=ax[0],x=df1.room_type, y=df1.avg_price)
# ax[0].set_title('Avg price of different room_type in different neighbourhood_group')
 
sns.barplot(ax=ax[1],x=df2.neighbourhood_group, y=df2.avg_price)
# ax[1].set_title('Avg price of different room_type in different neighbourhood_group')

sns.barplot(ax=ax[2],x=df3.neighbourhood_group, y=df3.avg_price, hue=df3.room_type)
# ax[2].set_title('Avg price of different room_type in different neighbourhood_group')

# %% [markdown]
# * Entire home/apt is costly than other room_type and shared_room is cheaper.
#
# * Properties in Manhattan are costly as compared to other neighbourhoo_group. The average price of properties in Queen and Staten Island are almost same. Properties in Bronx and Queens are cheaper
#
# * The Entire home/apt in Bronx, shared room in Queen and  Private room in Bronx are cheaper.
#
# * The Entire home/apt in Manhattan, shared room in Manhattan and  Private room in Manhattan are expensive
#
# * The avg price of Private room in Bronx, Queen and Staten Island are almost same.
#
# * The avg price of Shared room in Bronx, Brooklyn and Queens are almost same.
#
# * The avg price of entire home/apt in Staten Island, Bronx are almost same.

# %%
display(df1),display(df2),display(df3)
# Out:
#          room_type   avg_price
# 0  Entire home/apt  162.545860
# 1     Private room   79.042424
# 2      Shared room   59.382731
#   neighbourhood_group   avg_price
# 0               Bronx   77.427935
# 1            Brooklyn  105.737686
# 2           Manhattan  145.965614
# 3              Queens   88.904437
# 4       Staten Island   89.235616
#    neighbourhood_group        room_type   avg_price
# 0                Bronx  Entire home/apt  112.195592
# 1                Bronx     Private room   60.698906
# 2                Bronx      Shared room   47.254237
# 3             Brooklyn  Entire home/apt  148.222025
# 4             Brooklyn     Private room   70.329087
# 5             Brooklyn      Shared room   48.283570
# 6            Manhattan  Entire home/apt  181.710666
# 7            Manhattan     Private room   98.057700
# 8            Manhattan      Shared room   75.939785
# 9               Queens  Entire home/apt  131.328388
# 10              Queens     Private room   65.732319
# 11              Queens      Shared room   46.989691
# 12       Staten Island  Entire home/apt  121.089286
# 13       Staten Island     Private room   62.292553
# 14       Staten Island      Shared room   57.444444
# (None, None, None)

# %% [markdown]
# ### Price at which most of the properties are available

# %%
df1=df.price.value_counts().head(10)

# %%
p3=df1.plot.bar()
p3.set_xlabel('Price')
p3.set_ylabel('number of properties at given price')
p3.set_xticklabels(p3.get_xticklabels(),rotation= 45 )
# Out:
# [Text(0, 0, '100.0'),
#  Text(0, 0, '150.0'),
#  Text(0, 0, '50.0'),
#  Text(0, 0, '60.0'),
#  Text(0, 0, '200.0'),
#  Text(0, 0, '75.0'),
#  Text(0, 0, '80.0'),
#  Text(0, 0, '65.0'),
#  Text(0, 0, '70.0'),
#  Text(0, 0, '120.0')]

# %% [markdown]
# * Most of the properties listed on Airbnb costs between 100 to 200 dollar per day

# %% [markdown]
# ### Top 5 host with minimum possible earnings

# %%
# Consider the following column from the original dataframe
df6=df[['host_id','host_name','minimum_nights','price','number_of_reviews']]

# create new earning column
df6['earnings']= (df6.minimum_nights*df6.price*df6.number_of_reviews)

# Groupby the host name and sum up the minimum possible earnigs
top_earner_df=df6.groupby(['host_id','host_name'])['earnings'].sum().reset_index().sort_values('earnings',ascending=False).rename(columns={'earnings':'min_possible_earning'}).head()
top_earner_df
# Out:
#         host_id host_name  min_possible_earning
# 11527  10992588      Joni            14079600.0
# 9068    7245581   Michael             2911851.0
# 18894  31626212      Troy             2609937.0
# 5934    3831783    Shahar             2300510.0
# 10651   9716281     Sarah             2275000.0

# %%
df1=df[(df.host_id==10992588)|(df.host_id==7245581)|(df.host_id==31626212)|(df.host_id==3831783)|(df.host_id==9716281)]

# %%
df2=df1.groupby(['host_name'])['calculated_host_listings_count'].count().reset_index()
df3=df1.groupby(['host_name'])['number_of_reviews'].sum().reset_index()
df4=df1.groupby(['host_name'])['minimum_nights'].median().reset_index()
df5=df1.groupby(['host_name'])['price'].mean().reset_index().rename(columns={'price':'averg_price'})


plt.figure(figsize=(25,8))

plt.subplot(2,4,1)
sns.barplot(x=top_earner_df.host_name, y=top_earner_df.min_possible_earning)

# plt.subplot(2,4,2)
# sns.barplot(x=df2.host_name, y=df2.calculated_host_listings_count)

# plt.subplot(2,4,3)
# sns.barplot(x=df5.host_name, y=df5.averg_price)

# plt.subplot(2,4,4)
# sns.barplot(x=df3.host_name, y=df3.number_of_reviews)

# plt.subplot(2,4,5)
# sns.barplot(x=df4.host_name, y=df4.minimum_nights)

# %%
df[(df.host_id==10992588)].groupby(['neighbourhood_group','room_type'])['name'].count().reset_index()
# Out:
#   neighbourhood_group        room_type  name
# 0            Brooklyn  Entire home/apt     2

# %% [markdown]
# *  Joni's earning is maximum (1.4 Cr) compared to other hosts
# *  His average room price is around 120$ with minimum_night stay of 200 nights
#
# *   He has listed only 2 times on Airbnb and has 580+ reviews
# * He owns 2 Entire home/apt in Brooklyn

# %% [markdown]
# ### Overall Correlation with Price

# %%
df1=df[['price','minimum_nights','number_of_reviews','calculated_host_listings_count']]
corr_df1=df1.corr()
sns.heatmap(corr_df1,annot=True).set_title('Overall Correlation with Price',fontsize =20)
# Out:
# Text(0.5, 1.0, 'Overall Correlation with Price')

# %% [markdown]
# * Most of the properties with cheaper price ,often gets more number of reviews as compare to the properties with higher price. That is maybe because people prefer renting cheaper property, which leads to more reviews.
#
# * Less minimum nights, higher is the number of review .
# This is because if a host gets rental for his properties, for 60 days, then he  will not get booking for atleast 60 days, he gets atmost 1 review within 2-3 months.
# And the host who has set minimum_nights as 1 or  2 will get atleast 1 booking within2-3 months, hence he will get atleast 1 review with in 2-3 months.
#
#
#
# * number_of_reviews is negativly correlated with host listing count, this doesn't make sense
# * we see that small positive correlation between price and number of host isting counts (17%) there is slite rise in price with increase in host listing counts.

# %% [markdown]
# ## **MINIMUM_NIGHTS**

# %% [markdown]
# ### Average minimum_night of differtent room types

# %%
mini=df.groupby(['room_type'])['minimum_nights'].mean().reset_index().sort_values('minimum_nights',ascending=False)
mini
# Out:
#          room_type  minimum_nights
# 0  Entire home/apt        8.541840
# 2      Shared room        6.522847
# 1     Private room        5.297963

# %%
sns.barplot(x='room_type',y='minimum_nights',data=mini)

# %% [markdown]
# *  Entire home/apt	room type have highest avaerage minimum night stay of 8 night
# *  Private room types have least least avaerage minimum night stay of 5 night

# %% [markdown]
# ### What are the mimimum_nights stay set by most of the host and the average price of property with particular minimum nights

# %%
df1=df.groupby(['minimum_nights']).agg({'price':'mean','name':'count'}).reset_index().rename(columns={'name':'property_counts'}).sort_values('property_counts',ascending=False).head()
df1
# Out:
#     minimum_nights       price  property_counts
# 0                1  104.978092            12067
# 1                2  123.830233            11080
# 2                3  128.938069             7375
# 29              30  136.934311             3493
# 3                4  131.487458             3066

# %%
plt.figure(figsize=(13,4))

plt.subplot(1,2,1)
sns.barplot(x=df1.minimum_nights, y=df1.property_counts)

plt.subplot(1,2,2)
sns.barplot(x=df1.minimum_nights, y=df1.price)

# %% [markdown]
# *  Maximum number of properties listed on Airbnb has minimum nights stay of 1, 2 and 3 nights
#
# *   Lesser the minimum nights cheaper is the price this implies that they are postive correlated

# %%
df1 = df[['price', 'minimum_nights']]
corr_df1=df1.corr()
sns.heatmap(corr_df1,annot=True)

# %% [markdown]
# * minimum nights and price has no correlation, our asumption is false

# %% [markdown]
# ## **AVALABILITY_365**

# %% [markdown]
# ### availability_365 overview on a map (scatter plot)

# %%
df1=df[df.availability_365<=160]
df2=df[(df.availability_365>160)]

plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
sns.scatterplot(y=df1.latitude, x=df1.longitude, hue=df1.availability_365, size=df1.availability_365, sizes=(250, 20) ).set(title='availability_365 of properities  from 0 to 150')

plt.subplot(1,2,2)
sns.scatterplot(y=df2.latitude, x=df2.longitude, hue=df2.availability_365, size=df2.availability_365, sizes=(250, 20) ).set(title='availability_365 of properities from 200 to 360')
# Out:
# [Text(0.5, 1.0, 'availability_365 of properities from 200 to 360')]

# %% [markdown]
# ### Availability percentage of properties in different neighbourhood_group

# %%
plt.figure(figsize=(20,5))

plt.subplot(1,2,1)
sns.scatterplot(y=df.latitude,x=df.longitude,hue=df.neighbourhood_group).set(title='neighbourhood_group')

plt.subplot(1,2,2)
sns.scatterplot(y=df.latitude, x=df.longitude, hue=df.availability_365, size=df.availability_365, sizes=(250, 20) ).set(title='availability_365')
# Out:
# [Text(0.5, 1.0, 'availability_365')]

# %%
df2=df.groupby(['neighbourhood_group','room_type'])['availability_365'].apply(lambda x: (x.sum()*100)/(365*x.count())).reset_index()
df2.head()
# Out:
#   neighbourhood_group        room_type  availability_365
# 0               Bronx  Entire home/apt         42.415185
# 1               Bronx     Private room         46.889058
# 2               Bronx      Shared room         41.718133
# 3            Brooklyn  Entire home/apt         25.634178
# 4            Brooklyn     Private room         27.298721

# %%
plt.figure(figsize=(20,15))
df1=df.groupby(['neighbourhood_group'])['availability_365'].apply(lambda x: (x.sum()*100)/(365*x.count()))
df2=df.groupby(['neighbourhood_group','room_type'])['availability_365'].apply(lambda x: (x.sum()*100)/(365*x.count())).reset_index()

plt.subplot(2,2,1)
sns.barplot(x=df2.neighbourhood_group, y=df2.availability_365, hue=df2.room_type).set(title='Availability percentage of different room_type in different neighbourhood_group')
plt.subplot(2,2,2)
df1.plot.pie(autopct="%.1f%%")

# %% [markdown]
# * One of the factor on which the availability of property depends is booking.
#
# * Availability of properties for booking in Manhattan and in the north part of Brooklyn  are less as compared to other neighourhood_group, This shows that the properies in this region are often booked, hence People prefer renting apartment in Manhattan and in the northern part of Brooklyn. And they mostly prefer private room and entire home/apt over shared room
#
# * People in Queen also prefer renting private room and entire home/apt over shared room
#
# * Availability of properties for booking in Staten Island is more as compared to other neighourhood_group, people in Staten Island prefer renting shared room. Most of the Entire hom/apt and private room are vacant

# %% [markdown]
# ## **NAME**

# %% [markdown]
# ### Most Popular Descriptive words used by the host to describe their properties

# %%
# consider the name column only
df10=df[['name']]
# Split string in the name column into list of words
df10['name']=df10['name'].apply(lambda x: x.split())
# Explode the list in the name column
df11=df10.name.explode().reset_index()
# conver all the capital later into small later
df11['name']=df11['name'].apply(lambda x: x.lower())
# count the unique number of words
df12=df11.name.value_counts().reset_index().rename(columns={'index':'name','name':'counts'})
df12.head()
# Out:
#         name  counts
# 0         in   16045
# 1       room    9323
# 2    bedroom    6858
# 3    private    6832
# 4  apartment    5827

# %%
# Select the descriptive words from the name in the above dataframe
df13=df12[df12['name'].apply(lambda x: x in ['cozy','spacious','sunny','beautiful','large','central','luxury','new','charming','great','quite','clean','amazing','duplex','lovely'])].rename(columns={'name':'descriptive_words',0:'counts'})
df13.head()
# Out:
#    descriptive_words  counts
# 5               cozy    4577
# 11          spacious    3256
# 20             sunny    2487
# 23         beautiful    2197
# 29             large    1782

# %%
# Plot the count of each words
plt.figure(figsize=(16,5))
sns.barplot(x='descriptive_words', y='counts', data=df13)
